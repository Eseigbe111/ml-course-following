# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# To create a simple plot
plt.plot();

# %%
# Instead of doing plt.plot(); :
plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4]);

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y)

# %%
#  We can also plot using
# 1) Mthd 1
fig = plt.figure() # creates a figure
ax = fig.add_subplot() # adds sm axes
plt.show()

# %%
# 2) Mthd 2
fig = plt.figure()
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y) # this adds sm data on the graph
plt.show()

# %%
# 3) Mthd 3 (This is recommended i.e the one we will using)
fig, ax = plt.subplots() # fig is already = plt.figure() above
ax.plot(x, y); #This adds some data on the plot

# %%
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250]);

# %% [markdown]
# # 004 Anatomy Of A Matplotlib Figure

# %% [markdown]
# #### Matplotlib example workflow

# %%
# 0) import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1) Prepare the data u want to plot
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2) Setup plot
fig, ax = plt.subplots(figsize=(10, 10)) # the figsize (10, 10), is just width and height, 
# which is usually x and y. it is the dimensions of the plot

# 3) Plot data i.e adding data to our axes
ax.plot(x, y)

# 4) Customize plot: This is naming the plot and their axes
ax.set(title="Simple Plot",
      xlabel="x-axis",
      ylabel="y-axis")

# 5) Save & show (u save the whole figure): U can save it anywhere. But since i have the images 
# folder, i can save them there too.
fig.savefig("images/sample-plot1.png")

# %% [markdown]
# # 005 Scatter Plot And Bar Plot

# %% [markdown]
# ## Making figures with NumPy arrays:
# We want:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
# 1) Create sm data 
x = np.linspace(0, 10, 100) #(start, stop, num)
x[:10] # we want to see the first 10
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# 2) Plot the data and create a line plot (the default in matplotlib is a line plot)
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# 3) Use the same data to create a scattered plot
fig, ax = plt.subplots()
ax.scatter(x, x**2)

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x))

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %%
# 4) Making a Bar plot
# Make a plot from a dictionary
nut_butter_prices = {"Almond butter": 10,
                     "Peanut butter": 8,
                     "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar( nut_butter_prices.keys(), nut_butter_prices.values());
ax.set(title="Dan's Nut Butter store",
      ylabel="Price ($)");

# %% [markdown]
# # 006 Histograms And Subplots

# %%
# 5) There are horizontal bars too
fig, ax = plt.subplots()
ax.barh( nut_butter_prices.keys(), nut_butter_prices.values());
ax.set(title="Dan's Nut Butter store",
      ylabel="Price ($)");

# %%
fig, ax = plt.subplots()
ax.barh( list(nut_butter_prices.keys()), list(nut_butter_prices.values()));
ax.set(title="Dan's Nut Butter store",
      ylabel="Price ($)");

# %%
# 6) Making a Histogram
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x)
# Out:
# (array([  2.,  19.,  55., 120., 186., 230., 183., 135.,  50.,  20.]),
#  array([-3.35451394, -2.7501217 , -2.14572946, -1.54133723, -0.93694499,
#         -0.33255275,  0.27183948,  0.87623172,  1.48062396,  2.08501619,
#          2.68940843]),
#  <BarContainer object of 10 artists>)

# %%
# 7) Making multiple plot happen together i.e a subplot
# Two options for subplot
# a) Option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                            ncols=2,
                                            figsize=(10, 5));

# Plot to each difft axis
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %% [markdown]
# # 007 Subplots Option 2

# %%
# a) Option 2
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10, 5))

# Plot to each difft index
# now, we use difft ax[0, 0] or ax[0, 1] etc so we can see the various plots
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# # 009 Plotting From Pandas DataFrames

# %%
import pandas as pd

# %%
# Make a dataframe
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range("1/1/2026", periods=1000))
ts
# Out:
# 2026-01-01   -0.452131
# 2026-01-02   -0.526523
# 2026-01-03    0.309292
# 2026-01-04   -0.565145
# 2026-01-05   -0.777451
#                 ...
# 2028-09-22   -0.534447
# 2028-09-23   -0.591163
# 2028-09-24    0.727260
# 2028-09-25    0.880033
# 2028-09-26   -1.424555
# Freq: D, Length: 1000, dtype: float64

# %%
ts = ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# The code below is a prototype to convert any coulmn that is string to numeric values
car_sales["Price"] = (car_sales["Price"].str.replace("$", "", regex=False)
    .str.replace(",", "", regex=False).astype(float)
)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
# Adding a car sales date
car_sales["Sale Date"] = pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date
# 0  Toyota  White         150043      4   4000.0 2020-01-01
# 1   Honda    Red          87899      4   5000.0 2020-01-02
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03
# 3     BMW  Black          11179      5  22000.0 2020-01-04
# 4  Nissan  White         213095      4   3500.0 2020-01-05
# 5  Toyota  Green          99213      4   4500.0 2020-01-06
# 6   Honda   Blue          45698      4   7500.0 2020-01-07
# 7   Honda   Blue          54738      4   7000.0 2020-01-08
# 8  Toyota  White          60000      4   6250.0 2020-01-09
# 9  Nissan  White          31600      4   9700.0 2020-01-10

# %%
# Making a Total sales column
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2020-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0 2020-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0 2020-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0 2020-01-05      41500.0
# 5  Toyota  Green          99213      4   4500.0 2020-01-06      46000.0
# 6   Honda   Blue          45698      4   7500.0 2020-01-07      53500.0
# 7   Honda   Blue          54738      4   7000.0 2020-01-08      60500.0
# 8  Toyota  White          60000      4   6250.0 2020-01-09      66750.0
# 9  Nissan  White          31600      4   9700.0 2020-01-10      76450.0

# %%
# Let's plot the total sales
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %% [markdown]
# # 012 Plotting from Pandas DataFrames 3

# %%
# How about a bar graph?
x = np.random.rand(10, 4)
x
# 1) Turn it into a dataframe
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.477779  0.517439  0.782543  0.688093
# 1  0.814610  0.625912  0.036968  0.405472
# 2  0.513231  0.003220  0.248651  0.301386
# 3  0.833694  0.990316  0.059832  0.878913
# 4  0.559034  0.786218  0.742868  0.705865
# 5  0.778689  0.123561  0.824681  0.973431
# 6  0.753705  0.241954  0.434614  0.450461
# 7  0.774098  0.479259  0.409181  0.009285
# 8  0.302062  0.308015  0.059061  0.308604
# 9  0.368706  0.881236  0.971320  0.885369

# %%
# Plotting the bar graph
df.plot.bar();

# %%
df.plot(kind="barh"); # this is horizontal bar chart

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2020-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0 2020-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0 2020-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0 2020-01-05      41500.0
# 5  Toyota  Green          99213      4   4500.0 2020-01-06      46000.0
# 6   Honda   Blue          45698      4   7500.0 2020-01-07      53500.0
# 7   Honda   Blue          54738      4   7000.0 2020-01-08      60500.0
# 8  Toyota  White          60000      4   6250.0 2020-01-09      66750.0
# 9  Nissan  White          31600      4   9700.0 2020-01-10      76450.0

# %%
car_sales.plot.bar(x="Make", y="Odometer (KM)");

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
# The usefulness of using "plot.hist()" is that hist() can take-in bins. bins are the columns 
# that make bars in the histogram
car_sales["Odometer (KM)"].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # 013 Plotting from Pandas DataFrames 4

# %%
#  Let's try on another dataset
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create an histogram of age
heart_disease["age"].plot.hist();

# %%
heart_disease["age"].plot.hist(bins=20);

# %% [markdown]
# # 014 Plotting from Pandas DataFrames 5

# %% [markdown]
# ### Which one should i use? (pyplot vs matplotlib OO Mthd(i.e object oriented mthd))
# * when plotting smth quickly, it is okay to use the pyplot mthd
# * When plotting smth more advanced, u can use the OO mthd

# %%
# OO mthd in action
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# 1) pyplot mthd : we will plot chol v age
over_50.plot(x="age",
            y="chol",
            kind="scatter",
            figsize=(10, 5),
            c="target"); # c is colour, chol is cholesterol

# %%
# 2) OO mthd mixed with pyplot mthd
fig, ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind="scatter",
            x="age",
            y="chol",
            c="target",
            ax=ax); 
ax.set_xlim([45, 100]); #This changes our x-axis from 45 to 100 instead of 50 to 80 which is default

# %% [markdown]
# # 015 Plotting from Pandas DataFrames 6

# %%
# OO mthd from scratch
fig, ax = plt.subplots(figsize=(10, 6)) # 10 is length of x and y = 6 is length of y

# Plot the data
scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"]);

# Customize the plot
ax.set(title="Heart Disease and Cholesterol Levels",
      xlabel="Age",
      ylabel="Cholesterol");

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

# Add an horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle="--");

# %% [markdown]
# # 016 Plotting from Pandas DataFrames 7

# %% [markdown]
# ##### So now, we are really going to step it up a notch, we are going to see the full power of the matplotlib OO mthd. we're gonna build upon what we've done above. So we're going to add a subplot to this, so we can visualize cholesterol levels and we might get our over 50 data frame from here so we can stop having to scroll up.

# %%
# A Subplot of chol, age and thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10, 10));

# 1) THIS IS FOR THE CHOLESTEROL
# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"]);

# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol");

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target");

# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--");

# 2) THIS IS FOR THE THALACH
# Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50["target"]);

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate");

# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target");

# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle="--");

# Add atitle to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# NOW FOR THE GRAPHS, U COULD HAVE A SCATTERED PLOT AND A HISTOGRAM OR ANY PLOT, NOT NECESSARILY
# A SECOND SCATTERED PLOT

# %%
# FOR THE PLOT ABOVE WE CAN REMOVE xlabel value from ax0 and use sharex after figsize=(10, 10), 
# bcos we have the same xlabel axis. This is what i mean below:

# A Subplot of chol, age and thalach
fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10, 10),
                              sharex=True);

# 1) THIS IS FOR THE CHOLESTEROL
# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"]);

# Customize ax0
ax0.set(title="Heart Disease and Cholesterol Levels",
       # xlabel="Age",
       ylabel="Cholesterol");

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target");

# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--");


# 2) THIS IS FOR THE THALACH
# Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50["target"]);

# Customize ax1
ax1.set(title="Heart Disease and Max Heart Rate",
       xlabel="Age",
       ylabel="Max Heart Rate");

# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target");

# Add a meanline
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle="--");

# Add atitle to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %% [markdown]
#  # 017 Customizing Your Plots

# %%
# These are various styles available on matplotlib
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000.0 2020-01-01       4000.0
# 1   Honda    Red          87899      4   5000.0 2020-01-02       9000.0
# 2  Toyota   Blue          32549      3   7000.0 2020-01-03      16000.0
# 3     BMW  Black          11179      5  22000.0 2020-01-04      38000.0
# 4  Nissan  White         213095      4   3500.0 2020-01-05      41500.0

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-v0_8-whitegrid'); #This will update matplotlib internally

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-v0_8');
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# Creating sm data
x = np.random.randn(10, 4) # this is 10 rows and 4 cols
x
# Out:
# array([[ 0.81973302, -0.88177653,  2.05651425, -0.12963186],
#        [ 1.5826886 ,  0.20701269, -0.46606602, -0.27586831],
#        [ 0.97788506, -1.16886808,  1.39980396, -0.93648364],
#        [ 0.21743338, -0.40264447,  0.08654042, -1.14762898],
#        [ 1.43101666, -0.26693726, -0.36669794, -0.5065372 ],
#        [ 0.28066542,  0.31891333,  0.55512489,  0.04841997],
#        [-1.94170091,  0.44658869,  2.16212028,  1.08419171],
#        [-0.38005752, -0.27630548, -0.00778216,  1.1198379 ],
#        [ 1.25054868,  0.66091094,  0.02595064, -2.56593472],
#        [ 0.43917821, -1.26502826,  1.81040119, -0.61868936]])

# %%
import pandas as pd

# %%
# Creating a table
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.819733 -0.881777  2.056514 -0.129632
# 1  1.582689  0.207013 -0.466066 -0.275868
# 2  0.977885 -1.168868  1.399804 -0.936484
# 3  0.217433 -0.402644  0.086540 -1.147629
# 4  1.431017 -0.266937 -0.366698 -0.506537
# 5  0.280665  0.318913  0.555125  0.048420
# 6 -1.941701  0.446589  2.162120  1.084192
# 7 -0.380058 -0.276305 -0.007782  1.119838
# 8  1.250549  0.660911  0.025951 -2.565935
# 9  0.439178 -1.265028  1.810401 -0.618689

# %%
df.plot(kind="bar");

# %%
# Customize our plot with the set()
ax = df.plot(kind="bar");

# Add sm labels and a title
ax.set(title="Random Number Bar Graph from DataFrame",
      xlabel="Row number",
      ylabel="Random number");
